# %% [markdown]
# Write a Python program that creates an iterator from a string and uses a while loop to print each character
# one by one.

# %%
string = input('Input: ')
iterator = iter(string)
while True:
  try:
   ch = next(iterator)
   print(ch)
  except StopIteration:
    break
# Out:
# Input: hello world
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# Problem 1) Write a Python Program to Create a Class which has Attributes of
# Mobile Phone, Display to User through Derived Class.

# %%
class Derived:
  def __init__(self,model,price,brand):
    self.brand = brand
    self.model = model
    self.price = price

  def deliver(self):
    print(f'The mobile is : {self.brand} brand')
    print(f'The model is : {self.model}')
    print(f'The price of this model is : {self.price}')

obj = Derived('Realme 08','10,000','Realme')
obj2 = Derived('Note 10 pro max','30,000','MI')
obj.deliver()
obj2.deliver()
# Out:
# The mobile is : Realme brand
# The model is : Realme 08
# The price of this model is : 10,000
# The mobile is : MI brand
# The model is : Note 10 pro max
# The price of this model is : 30,000

# %% [markdown]
# Problem 2) Write a Python Program to Create a Class and Declare & Initialize
# attributes with Private Access Modifier and Create Method to Display Attributes
# to User through Child Class.

# %%
class name_Marks:

    def __init__(self,name,marks):
      self.name = name
      self.marks = marks
    def marks():


obj = Car()
print(Car.name)
# Out:
# Hello
# Tamim
