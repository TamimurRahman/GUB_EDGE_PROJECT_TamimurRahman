# %%
import pandas as pd
data = [10,20,30,40]
series = pd.Series(data)
print(series)

print(series[2])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 30

# %%
df = pd.Series(data, index=['A', 'B', 'C','E'])
print(df['A'])
# Out:
# 10

# %%
import pandas as pd

# Corrected code
data = {'Name': ['Alice', 'Bob', 'Charls'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)  # Use DataFrame (not Dataframe)
print(df)
# Out:
#      Name  Age
# 0   Alice   25
# 1     Bob   30
# 2  Charls   35

# %%
print(df['Name'])
# Out:
# 0     Alice
# 1       Bob
# 2    Charls
# Name: Name, dtype: object

# %%
print(df.iloc[1])
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
print(df.loc[1, 'Name'])
# Out:
# Bob

# %%
df = pd.DataFrame({'Category': ['A', 'A', 'B', 'B'], 'Value': [10, 15, 20, 25]})
print(df)
# Out:
#   Category  Value
# 0        A     10
# 1        A     15
# 2        B     20
# 3        B     25

# %%
df = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
print(df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
