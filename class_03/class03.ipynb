# %%
grade = {'Alice':85 ,'Bob':92, 'Charlie': 33}
print(grade)
# Out:
# {'Alice': 85, 'Bob': 92, 'Charlie': 33}

# %%
students = {
    'Alice':{'Age':18,'Grade':85,'Nick_Name':"Alicen Burger"},
    'Bob':{'Age':17,'Grade':92},
    'Charlie':{'Age':20,'Grade':93}
}
print(students['Alice']['Grade'])
# Out:
# 85

# %%
site_string = "jafricode.com"
byte = bytes(site_string, 'utf-8')
print(byte)
# Out:
# b'jafricode.com'

# %%
num=3
ans = bytes(num)
print(ans)
# Out:
# b'\x00\x00\x00'

# %%
a = 20
type(a)
b=20.03
type(b)
# Out:
# float

# %%
str = '32'
print(type(str))
c_str = int(str)
print(type(c_str))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#print('value'+123)
a = 12
c = 12
print(a+c)
gip = 123
gip_str1 = str(gip)
print(gip_str1)
#print(type(str1))
# Out:
# 24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ed41c754be40> in <cell line: 6>()
#       4 print(a+c)
#       5 gip = 123
# ----> 6 gip_str1 = str(gip)
#       7 print(gip_str1)
#       8 #print(type(str1))
#
# TypeError: 'str' object is not callable

# %%
#print(range(1,11,1))
for i in range(1,11,2):
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = input("Enter first number:" )
b = input("Enter second number:")
if(a>b):
  print("a is bigger than b--->",a)
elif(a<b):
  print("b is bigger than a--->",b)
else:
  print("a is equal to b--->",a)
# Out:
# Enter first number:10
# Enter second number:20
# b is bigger than a---> 20

# %%
#lipear
num = input("Input an number : ")
for i in range(2,num/2):
  if(num%2==0):
    print(num,"is not a prime number")
    break
  else:
    print(num,"is a prime number")
    break
# Out:
# Input an number : 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-da3a0d2d9814> in <cell line: 3>()
#       1 #lipear
#       2 num = input("Input an number : ")
# ----> 3 for i in range(2,num/2):
#       4   if(num%2==0):
#       5     print(num,"is not a prime number")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
a = input("Input a: ")
b = input("Input b: ")
c = input("Input c: ")
d = input("Input d: ")
if(a>b):
  if(a>c):
    if(a>d):
      print(a ," is the biggest number")
elif(b>c):
  if(b>d):
    print(b ," is the biggest number")
elif(c>d):
  print(c ," is the biggest number")
else:
  print(d ," is the biggest number")
# Out:
# Input a: 4
# Input b: 3
# Input c: 5
# Input d: 2

# %%
#licture 03 exercise in hw 1 to 09
