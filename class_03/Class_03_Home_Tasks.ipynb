# %%
# no 1
num = int(input("Enter an Number: "))
if(num%2==0):
    print("Even")
else:
    print("Odd")
# Out:
# Enter an Number: 0
# Even

# %%
#no 2
num = int(input("Enter a Number: "))
if(num<50):
    print("Fail")
else:
    print("Pass")
# Out:
# Enter a Number: 50
# Pass

# %%
#no 3
num = int(input("Enter a numbet: "))
if(num<0):
    print("Negative")
elif(num>0):
    print("Positive")
else:
    print("Zero")
# Out:
# Enter a numbet: 0
# Zero

# %%
#no 3


num = int(input("Enter a number: "))
match num:
    case  num if num<0:
        print("Negative")
    case num if num>0:
        print("Positive")
    case _:
        print("Zero")
# Out:
# Enter a number: 1
# Positive

# %%
#no 04
'''
Write a program that takes a score from the user and assigns a
grade: 90+ = "A", 80-89 = "B", 70-79 = "C", 60-69 = "D", and below
60 = "F".
'''
marks = int(input("Enter your marks: "))
print("The grade is: ")
if(marks>=90):
    print("A")
elif(marks>=80):
    print("B")
elif(marks>=70):
    print("C")
elif(marks>=60):
    print("D")
else:
    print("F")
# Out:
# Enter your marks: 59
# The grade is:
# F

# %%
#04
marks = int(input("Enter your marks: "))
print("The grade is: ")
match marks:
    case marks if marks>=90:
        print("A")
    case marks if marks>=80:
        print("B")
    case marks if marks>=70:
        print("C")
    case marks if marks>=60:
        print("D")
    case _:
        print("Fail")
# Out:
# Enter your marks: 65
# The grade is:
# D

# %%
#05
'''
Write a program to check if a given year is a leap year. A leap
year is divisible by 4, but if the year is divisible by 100, it must also
be divisible by 400 to be a leap year.
'''
year = int(input("Input year: "))

print("The year is:")

if((year%4 == 0 and year%100!=0) or year%400==0):
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Input year: 2023
# The year is:
# Not leap year

# %%
#06
'''
Write a program that takes three numbers from the user and
prints the largest of the three.
'''
a,b,c =input("Input three numbers: ")
print(a,b,c)
print("The maximum value is : ")
if(a>=b and a>=c):
    print(a," a is bigger than above three numbers.")
elif(b>=c):
    print(b," b is  bigger than above three numbers.")
else:
    print(c," c is bigger than above three numbers.")
# Out:
# Input three numbers: 13  10 13
# 13 10 13
# The maximum value is :
# 13  a is bigger than above three numbers.

# %%
#no 7
'''
Write a program that simulates a simple ATM. It should check
the user’s balance and allow them to withdraw money, making sure
the balance never goes negative. If the balance is insufficient, print
a warning message.
'''


initialblance = 10000

while (1):
    withdraw = int(input("Input in your amount: "))
    initialblance = initialblance-withdraw
    if(initialblance<=0):
        print("You cant withdraw the money you blance is insufficient!!!")
        initialblance = initialblance+withdraw
        break
    else:
        print("you can withdraw money & you current blance is : ",initialblance)
# Out:
# Input in your amount: 11000
# You cant withdraw the money you blance is insufficient!!!

# %%
#no 8
'''
Write a program that takes three side lengths of a triangle from
the user and determines whether the triangle is Equilateral (all
sides equal), Isosceles (two sides equal), or Scalene (all sides
different). Additionally, check if it's a valid triangle.
'''

a,b,c = map(int,input("Input three sides of a triangle: ").split())


if(a+b>c and b+c>a and a+c>b):
    print("Valid Triangle")
    if(a==b or a==c or b==c):
      print("Isosceles Triangle")
    elif(a==b and b==c and a==c):
      print("Equilateral Triangle")
    elif(a==b or a==c or b==c):
      print("Isosceles Triangle")
    else:
      print("Scalene Triangle")
else:
      print("Not valid triangle")
# Out:
# Input three sides of a triangle: 3 4 5
# Valid Triangle
# Scalene Triangle

# %%
#no 9
'''
Write a program that converts temperatures from Fahrenheit to
Celsius (celsius = (fahrenheit - 32) * 5/9) and checks whether the
converted temperature is above freezing (0°C) or below freezing.
Add conditions to handle extreme temperatures:

"It's extremely cold!" for below -30°C

"It's extremely hot!" for above 40°C
'''
fahrenheit = int(input("Input fahrenheit tempreature: "))
celsius = (fahrenheit - 32) * 5/9
print("The tempreature is : ",celsius," celsisus")

if(celsius<-30):
    print("It's extremely cold!")
elif(celsius<0):
    print("below freezing")
elif(celsius>40):
    print("It's extremely hot!")
else:
    print("above freezing")
# Out:
# Input fahrenheit tempreature: -7
# The tempreature is :  -21.666666666666668  celsisus
# below freezing
