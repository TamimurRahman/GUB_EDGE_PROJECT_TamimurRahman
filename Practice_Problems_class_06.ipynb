# %%
#problem_01
def area_calculate(a):
    pi = 3.141641
    print("Area of a circale: ",pi*(a**2))
    print("Area of rectangle: ",a**2)

area = int(input("Input area: "))
area_calculate(area)

# %%
#problem_02
name=input("Input name: ")
size = len(name.replace(' ',""))
print('Size of string : ',size)
# Out:
# Input name: Tamimur Rahman
# Size of string :  13

# %%
#problem_03
total_marks = float(input('Enter the total marks: '))
obtained_marks=float(input('Enter the obtain marks: '))

percentage = float(obtained_marks/total_marks)*100
print(percentage)
print(f'The percentage is : {percentage: .2f}%')
# Out:
# Enter the total marks: 5
# Enter the obtain marks: 3
# 60.0
# The percentage is :  60.00%

# %%
#problem_04
num = int(input("Input num: "))
sum = 0
for i in range(num):
     x = int(input("X: "))
     sum = sum+x
print("Average: ",sum/num)
# Out:
# Input num: 10
# X: 1
# X: 2
# X: 3
# X: 10
# X: 50
# X: 60
# X: 1
# X: 2
# X: 3
# X: 5
# Average:  13.7

# %%
'''
Write a Python Program to get Username from User that should Contain Only
Alpha or Numeric Data, not Special Character or White Space. And Length of
Username should be Equal to 8 or Less Than 20 Characters.
'''
flag = 1
name = input("Name: ")
for i in range(len(name)):
    if(((name[i]>='A' and name[i]<='Z') or (name[i]>='a' and name[i]<='z') or (name[i]>='0' and name[i]<'10')) and ((len(name)-1)>=10 and (len(name)<=20))):
           pass
    else:
      flag = 0
      break
if(flag==1):
    print("Valid")
else:
  print('Not valid')
# Out:
# Name: TamimurRahman
# Valid

# %%
#create an project user authentication uisng python

# %%
import random

# List of items
fruits = ['apple', 'banana', 'cherry', 'date']

# Select a random fruit
random_fruit = random.choice(fruits)
print(f"The random fruit selected is: {random_fruit}")
# Out:
# The random fruit selected is: date

# %%
str1 = "jafriCode Website"
x = str1.index('Website')
y = str1.index('C')
print(x)
print(y)
# Out:
# 10
# 5
