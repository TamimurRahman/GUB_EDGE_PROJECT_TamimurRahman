# %%
a = input('Enter any value between 5 and 9: ')
if((a!='quit')):
    raise ValueError('value should be between 5 and 9')
print('all ok')
# Out:
# Enter any value between 5 and 9: quit
# all ok

# %%
questions = [['Which language was used to create fb?','Python','French','Js','Php',4],
            ['What is the national fruits in bangladesh?','Mango','Banana','Jackfruit','Apple',3],
            ['What is the mano tree leaf color?','Green','Red','Yellow','Blue',1],
             ['What is your national fish?','Hilsha','Ruhi','katla','Puti',1]
            ]
levels = [1000,2000,3000,5000,10000,20000,40000,80000,160000,320000]
money = 0
for i in range(0,len(questions)):
    question = questions[i]
    print(f'Question for Rs. {levels[i]}')
    print(f'The question is:{question[0]}')
    print(f'a.{question[1]}   b.{question[2]}')
    print(f'a.{question[3]}   b.{question[4]}')
    option = int(input("Input your answer 1-4 or press 0 quit: "))
    if(option==0):
      print(quit)
      break
    if(option==question[len(question)-1]):
      print(f'Your answer is correct win {levels[i]}...')
      money = money+levels[i]
      if(i==4):
        money=10000
      elif(i==9):
        money=320000
      elif(i==14):
        money=1000000
    else:
      print('Wrong answer!!')
    print('\n\n')
print(f'Your take home money is {money}')
# Out:
# Question for Rs. 1000
# The question is:Which language was used to create fb?
# a.Python   b.French
# a.Js   b.Php
# Input your answer 1-4 or press 0 quit: 4
# Your answer is correct win 1000...
#
#
#
# Question for Rs. 2000
# The question is:What is the national fruits in bangladesh?
# a.Mango   b.Banana
# a.Jackfruit   b.Apple
# Input your answer 1-4 or press 0 quit: 3
# Your answer is correct win 2000...
#
#
#
# Question for Rs. 3000
# The question is:What is the mano tree leaf color?
# a.Green   b.Red
# a.Yellow   b.Blue
# Input your answer 1-4 or press 0 quit: 0
# ...
# Your take home money is 3000

# %%
questions = [
    ['Which language was used to create fb?', 'Python', 'French', 'Js', 'Php', 4],
    ['What is the national fruit in Bangladesh?', 'Mango', 'Banana', 'Jackfruit', 'Apple', 3],
    ['What is the mango tree leaf color?', 'Green', 'Red', 'Yellow', 'Blue', 1],
    ['What is your national fish?', 'Hilsha', 'Ruhi', 'Katla', 'Puti', 1],
    ['Which planet is known as the Red Planet?', 'Earth', 'Mars', 'Jupiter', 'Venus', 2],
    ['Who wrote "Romeo and Juliet"?', 'Mark Twain', 'William Shakespeare', 'Charles Dickens', 'J.K. Rowling', 2],
    ['What is the capital of France?', 'Berlin', 'Paris', 'Rome', 'Madrid', 2],
    ['Which organ purifies blood in the human body?', 'Heart', 'Lungs', 'Kidneys', 'Liver', 3],
    ['What is the largest ocean on Earth?', 'Atlantic', 'Indian', 'Pacific', 'Arctic', 3],
    ['Who discovered gravity?', 'Isaac Newton', 'Albert Einstein', 'Galileo', 'Niels Bohr', 1]
]

levels = [1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, 160000, 320000]
money = 0

for i in range(len(questions)):
    question = questions[i]
    print(f'Question for Rs. {levels[i]}')
    print(f'The question is: {question[0]}')
    print(f'a. {question[1]}   b. {question[2]}')
    print(f'c. {question[3]}   d. {question[4]}')
    option = int(input("Input your answer (1-4) or press 0 to quit: "))

    if option == 0:
        print("You chose to quit. Exiting the game...")
        break

    if option == question[-1]:
        print(f'Your answer is correct! You win Rs. {levels[i]}...')
        money = levels[i]
        money+=levels[i]
    else:
        print('Wrong answer!!')
        break

    print('\n\n')

print(f'Your take-home money is Rs. {money}')
# Out:
# Question for Rs. 1000
# The question is: Which language was used to create fb?
# a. Python   b. French
# c. Js   d. Php
# Input your answer (1-4) or press 0 to quit: 4
# Your answer is correct! You win Rs. 1000...
#
#
#
# Question for Rs. 2000
# The question is: What is the national fruit in Bangladesh?
# a. Mango   b. Banana
# c. Jackfruit   d. Apple
# Input your answer (1-4) or press 0 to quit: 3
# Your answer is correct! You win Rs. 2000...
#
#
#
# Question for Rs. 3000
# The question is: What is the mango tree leaf color?
# a. Green   b. Red
# c. Yellow   d. Blue
# Input your answer (1-4) or press 0 to quit: 0
# You chose to quit. Exiting the game...
# Your take-home money is Rs. 4000
