# %%
#program_01
def function_name():
    print("I am in the function.")
function_name()
# Out:
# I am in the function.

# %%
def multiple(num):
    for i in range(10,0,-1):
      mul = num*i
      print(f'{num} X {i} = {mul}')
num = int(input("Inpur: "))
multiple(num)
# Out:
# Inpur: 10
# 10 X 10 = 100
# 10 X 9 = 90
# 10 X 8 = 80
# 10 X 7 = 70
# 10 X 6 = 60
# 10 X 5 = 50
# 10 X 4 = 40
# 10 X 3 = 30
# 10 X 2 = 20
# 10 X 1 = 10

# %%
def show(name=' ', num=19):
    print(name)
    print(num)
show('Faisal',32)
# Out:
# Faisal
# 32

# %%
def show_name(f_name,l_name='jafri'):
    print(f_name + l_name)
#show_name('Faisal')
show_name('Faisal','Zamir')
# Out:
# FaisalZamir

# %%
def show_number(num1,num2=33):
    print("Num1 ",num1)
    print('Num2 ',num2)
show_number(num1=43)
# Out:
# Num1  43
# Num2  33

# %%
def area_calculate(a):
    pi = 3.141641
    print("Area of a circale: ",pi*(a**2))
    print("Area of rectangle: ",a**2)

area = int(input("Input area: "))
area_calculate(area)
# Out:
# Input area: 3
# Area of a circale:  28.274769
# Area of rectangle:  9

# %%
def show():
  a = 32
  b=12
  return (a+b)
  print("Execute-------")
print("Sum: ",show())
# Out:
# Sum:  44

# %%
def fun():
  a = 20
  c = a+x

a = 30
x = 10

# %%
lm = lambda x : x+2
print(lm(2))
# Out:
# 4

# %%
def area_calculate(a):
    pi = 3.141641
    print("Area of a circale: ",pi*(a**2))
    print("Area of rectangle: ",a**2)

area = int(input("Input area: "))
area_calculate(area)
