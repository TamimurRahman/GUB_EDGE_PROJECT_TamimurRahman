# %%
#problem_01
'''
List Manipulation: Create a list of your favorite five movies. Write a program to:
• Print the second movie in the list.
• Add a new movie to the end of the list.
• Remove the first movie from the list and print the updated list.
'''
muvies =[' The Shawshank Redemption','The Godfather','The Dark Knight','The Godfather Part II','12 Angry Men']

print("The second muve name: ",muvies[1])
muvies.append('The Return of the King')
print("Add a new movie to the end of the list: ",muvies)
muvies.pop(0)
print(muvies)
# Out:
# The second muve name:  The Godfather
# Add a new movie to the end of the list:  [' The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', 'The Return of the King']
# ['The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', 'The Return of the King']

# %%
#problem_02
'''
2. Dictionary Operations: Write a program to create a dictionary that stores information about a book (title,
author, year, and genre). Then:
• Print the title of the book.
• Update the year to the current year and print the updated dictionary.
'''
books={
    'Title':'To Kill a Mockingbird',
    'Author':'Harper Lee',
    'Year':' 1960',
    'Genre':'Fiction, Drama'
}
print('Book title name is: ',books['Title'])
books['Year']=2000
print("Update Book information: ",books)
# Out:
# Book title name is:  To Kill a Mockingbird
# Update Book information:  {'Title': 'To Kill a Mockingbird', 'Author': 'Harper Lee', 'Year': 2000, 'Genre': 'Fiction, Drama'}

# %%
'''
3. Tuple Unpacking: Create a tuple with three different data types (e.g., string, integer, float). Write a program
that:
Unpacks the tuple into three variables and prints each variable separately.
'''
tup = (1,'Tamim',20.19,True)
int_value,string_value,float_value,bool_value=tup
print("String:", string_value)
print("Integer:", int_value)
print("Float:", float_value)
print('bool : ',bool_value)
# Out:
# String: Tamim
# Integer: 1
# Float: 20.19
# bool :  True

# %%
'''
Set Operations: Create two sets: set A = {1, 2, 3, 4, 5} and set B = {4, 5, 6, 7, 8}. Write a program
to:
• Find and print the symmetric difference of the two sets.
'''
set_A = {1, 2, 3, 4, 5}
set_B = {4, 5, 6, 7, 8}
set_c = set_A.intersection(set_B)
set_
print(set_A-set_c)
print(set_A.symmetric_difference(set_B))
# Out:
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}
