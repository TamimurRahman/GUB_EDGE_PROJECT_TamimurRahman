# %%
import math
radius = 7.5
area = math.pi*radius**2
print(area)
print(round(area,2))
# Out:
# 176.71458676442586
# 176.71

# %%
f_name = input()
l_name = input()
print(f"Hello {f_name} {l_name} welcome!")
# Out:
# Tamimur
# Rahman
# Hello Tamimur Rahman welcome!

# %%
sentence= "Learning Python is fun!"
print(len(sentence))
print(sentence[9:15])
print(sentence[19:22])
# Out:
# 23
# Python
# fun

# %%
text = "Data Science is amazing!"
print(text.upper())
replaced_text = text.replace('amazing','challenging')
print(replaced_text)
print(text)
# Out:
# DATA SCIENCE IS AMAZING!
# Data Science is challenging!
# Data Science is amazing!

# %%
fruit=['apple','mango','banana','date','cherry']
print(f"The first fruit is {fruit[0]} and the last fruit is {fruit[len(fruit)-1]}")
fruit.append('Guava')
print(fruit)
fruit.pop(1)
print(fruit)
# Out:
# The first fruit is apple and the last fruit is cherry
# ['apple', 'mango', 'banana', 'date', 'cherry', 'Guava']
# ['apple', 'banana', 'date', 'cherry', 'Guava']

# %%
number = [2,4,6,8]
sum = 0
mul = 0
print("New numbwrs: ")
for i in number:
    sum = sum+i
    print(i**2,end=" ")

print("\nSum: ",sum)
# Out:
# New numbwrs:
# 4 16 36 64
# Sum:  20

# %%
#tuple
my_tuple = ("python",42,3,14,True)
print(my_tuple[2])
contains_true = True in my_tuple
print(contains_true)
# Out:
# 3
# True
