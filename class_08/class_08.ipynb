# %%
#Tuples
cars = ('Audi','Mercideis','BMW','Hundai','Tesla','Mercideis')
print('The length of list: ',len(cars))
print('Tuples: ',cars)
print(cars[1:])
# Out:
# The length of list:  6
# Tuples:  ('Audi', 'Mercideis', 'BMW', 'Hundai', 'Tesla', 'Mercideis')
# ('Mercideis', 'BMW', 'Hundai', 'Tesla', 'Mercideis')

# %%
cars=tuple(('A'))

print(cars[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-70877c28804a> in <cell line: 3>()
#       1 cars=tuple(('A'))
#       2
# ----> 3 print(cars[1])
#
# IndexError: tuple index out of range

# %%
cars = ('Audi','Mercidies','BMW')
li = list(cars)
print('The original tuple: ',cars)
li.append('Toyta')
print('convert into tuple to list and another new item :',li)
print(tuple(li))
print(cars)
# Out:
# The original tuple:  ('Audi', 'Mercidies', 'BMW')
# convert into tuple to list and another new item :  ['Audi', 'Mercidies', 'BMW', 'Toyta']
# ('Audi', 'Mercidies', 'BMW', 'Toyta')
# ('Audi', 'Mercidies', 'BMW')

# %%
cars = ('Audi','Mercidies','BMW')
cars = cars+('toyta',)
print(cars)
# Out:
# ('Audi', 'Mercidies', 'BMW', 'toyta')

# %%
names = ()
li = list(names)
for i in range(1,6,1):
    name = input('Input name: ')
    li.append(name)
new_li = [x.upper() for x in li]
names = tuple(li)
print('Original tuple : ',names)
print('Uppercase every string: ',tuple(new_li))
# Out:
# Input name: Tamim
# Input name: osman
# Input name: rahul
# Input name: shawn
# Input name: lllm
# Original tuple :  ('Tamim', 'osman', 'rahul', 'shawn', 'lllm')
# Uppercase every string:  ('TAMIM', 'OSMAN', 'RAHUL', 'SHAWN', 'LLLM')
# Original tuple :  ('Tamim', 'osman', 'rahul', 'shawn', 'lllm')

# %% [markdown]
# **Write a Python Program to get 10 Numbers from user, Store in Tuple, and Display only Odd Numbers getting from the Tuple.**

# %%
my_tuple = ()
for i in range(1,11,1):
  num = int(input("Input number: "))
  my_tuple = my_tuple+(num,)
print(my_tuple)
li = list(my_tuple)
new_li = [i for i in my_tuple if i%2!=0]
print(new_li)
# Out:
# Input number: 1
# Input number: 3
# Input number: 5
# Input number: 7
# Input number: 10
# Input number: 11
# Input number: 12
# Input number: 16
# Input number: 13
# Input number: 19
# (1, 3, 5, 7, 10, 11, 12, 16, 13, 19)
# [1, 3, 5, 7, 11, 13, 19]

# %%
val = (10,20,30,40,50)
car1,car2,car3 = val
print(car1,car2,car3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-26c314e04da1> in <cell line: 2>()
#       1 val = (10,20,30,40,50)
# ----> 2 car1,car2,car3 = val
#       3 print(car1,car2,car3)
#
# ValueError: too many values to unpack (expected 3)

# %%
dic = {'a':4,'b':1,'c':6,'d':7}
for i in dic:
    print(dic[i],end=" ")
print('\n')
for key,val in dic.items():
    print(key,' : ',val)
# Out:
# 4 1 6 7
#
# a  :  4
# b  :  1
# c  :  6
# d  :  7

# %%
dic = {'a':4,'b':1,'c':6,'d':7}
new_dic = {k:v for (k,v) in dic.items() if ''}

#dictonary
